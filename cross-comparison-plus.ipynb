# %% [markdown]
# The cross comparison method is proposed by Woz: https://supermemo.guru/wiki/Universal_metric_for_cross-comparison_of_spaced_repetition_algorithms#Algorithmic_contest:_SuperMemo_2_vs._SuperMemo_17

# %%
import pandas as pd
from pathlib import Path

dfs = []

for file in Path("./raw").glob("*.csv"):
    dfs.append(pd.read_csv(file))

df = pd.concat(dfs, ignore_index=True)
df.rename(columns={"R (SM17)": "R (SM-17)"}, inplace=True)
df.rename(columns={"R (SM16)": "R (SM-16)"}, inplace=True)
df.head()
# Out:
#    y  R (SM-16)  R (SM-17)   R (AVG)  R (MOVING-AVG)  R (FSRS-6-default)  \
# 0  1      0.841      0.866  0.641176        0.613784               0.660
# 1  1      0.684      0.548  0.557143        0.640863               0.582
# 2  1      0.698      0.667  0.900000        0.665267               0.582
# 3  1      0.810      0.981  0.593333        0.707050               0.740
# 4  1      0.796      0.916  0.595000        0.578715               0.633
#
#    R (FSRSv3)  R (FSRSv4)  R (FSRS-4.5)  R (FSRS-5)  R (FSRS-6)  \
# 0       0.720       0.545         0.640       0.603       0.660
# 1       0.464       0.340         0.478       0.444       0.582
# 2       0.464       0.340         0.478       0.444       0.582
# 3       0.730       0.503         0.654       0.622       0.740
# 4       0.645       0.474         0.585       0.548       0.633
#
#    R (ADVERSARIAL)
# 0              1.0
# 1              1.0
# 2              1.0
# 3              1.0
# 4              1.0

# %%
df.describe()
# Out:
#                    y      R (SM-16)      R (SM-17)        R (AVG)  \
# count  687662.000000  687662.000000  687662.000000  687662.000000
# mean        0.869773       0.853300       0.885862       0.868532
# std         0.336553       0.149112       0.130725       0.054881
# min         0.000000       0.005000       0.000000       0.064286
# 25%         1.000000       0.820000       0.846000       0.837106
# 50%         1.000000       0.905000       0.914000       0.881227
# 75%         1.000000       0.945000       0.984000       0.902819
# max         1.000000       0.999000       1.000000       0.996970
#
#        R (MOVING-AVG)  R (FSRS-6-default)     R (FSRSv3)     R (FSRSv4)  \
# count   687662.000000       687662.000000  687662.000000  687662.000000
# mean         0.864614            0.799649       0.833526       0.838677
# std          0.086074            0.119795       0.168778       0.155693
# min          0.134825            0.198000       0.000000       0.003000
# 25%          0.827587            0.734000       0.797000       0.795000
# 50%          0.881543            0.823000       0.887000       0.888000
# 75%          0.922229            0.889000       0.939000       0.942000
# max          0.997495            1.000000       1.000000       1.000000
#
#         R (FSRS-4.5)     R (FSRS-5)     R (FSRS-6)  R (ADVERSARIAL)
# count  687662.000000  687662.000000  687662.000000    687662.000000
# mean        0.845602       0.844404       0.855819         0.869766
# std         0.136136       0.137310       0.096222         0.260204
# min         0.027000       0.015000       0.207000         0.000000
# 25%         0.797000       0.796000       0.809000         0.900000
# 50%         0.886000       0.885000       0.876000         1.000000
# 75%         0.940000       0.940000       0.925000         1.000000
# max         1.000000       1.000000       1.000000         1.000000

# %%
from utils import cross_comparison_plus
import itertools

results = []

all_algorithms = ["FSRS-6", "FSRS-5", "FSRS-4.5", "FSRSv4", "FSRSv3", "SM-17", "SM-16", "AVG", "MOVING-AVG"]

for player, referee in itertools.combinations(all_algorithms, 2):
    results.append(cross_comparison_plus(df, player, referee))
results
# Out:
# [{'FSRS-5_evaluated_by_FSRS-6': 0.0856, 'FSRS-6_evaluated_by_FSRS-5': 0.0274},
#  {'FSRS-4.5_evaluated_by_FSRS-6': 0.0828,
#   'FSRS-6_evaluated_by_FSRS-4.5': 0.0262},
#  {'FSRSv4_evaluated_by_FSRS-6': 0.1154, 'FSRS-6_evaluated_by_FSRSv4': 0.0313},
#  {'FSRSv3_evaluated_by_FSRS-6': 0.1531, 'FSRS-6_evaluated_by_FSRSv3': 0.0328},
#  {'SM-17_evaluated_by_FSRS-6': 0.11, 'FSRS-6_evaluated_by_SM-17': 0.0383},
#  {'SM-16_evaluated_by_FSRS-6': 0.1271, 'FSRS-6_evaluated_by_SM-16': 0.0265},
#  {'AVG_evaluated_by_FSRS-6': 0.077, 'FSRS-6_evaluated_by_AVG': 0.0281},
#  {'MOVING-AVG_evaluated_by_FSRS-6': 0.0742,
#   'FSRS-6_evaluated_by_MOVING-AVG': 0.0399},
#  {'FSRS-4.5_evaluated_by_FSRS-5': 0.025,
#   'FSRS-5_evaluated_by_FSRS-4.5': 0.0291},
#  {'FSRSv4_evaluated_by_FSRS-5': 0.1064, 'FSRS-5_evaluated_by_FSRSv4': 0.0774},
#  {'FSRSv3_evaluated_by_FSRS-5': 0.1391, 'FSRS-5_evaluated_by_FSRSv3': 0.0618},
#  {'SM-17_evaluated_by_FSRS-5': 0.1072, 'FSRS-5_evaluated_by_SM-17': 0.0871},
#  {'SM-16_evaluated_by_FSRS-5': 0.1135, 'FSRS-5_evaluated_by_SM-16': 0.0649},
#  {'AVG_evaluated_by_FSRS-5': 0.0699, 'FSRS-5_evaluated_by_AVG': 0.0805},
#  {'MOVING-AVG_evaluated_by_FSRS-5': 0.0715,
#   'FSRS-5_evaluated_by_MOVING-AVG': 0.089},
#  {'FSRSv4_evaluated_by_FSRS-4.5': 0.1086,
#   'FSRS-4.5_evaluated_by_FSRSv4': 0.0781},
#  {'FSRSv3_evaluated_by_FSRS-4.5': 0.1404,
#   'FSRS-4.5_evaluated_by_FSRSv3': 0.0619},
#  {'SM-17_evaluated_by_FSRS-4.5': 0.1071,
#   'FSRS-4.5_evaluated_by_SM-17': 0.0847},
#  {'SM-16_evaluated_by_FSRS-4.5': 0.1138,
#   'FSRS-4.5_evaluated_by_SM-16': 0.0625},
#  {'AVG_evaluated_by_FSRS-4.5': 0.0702, 'FSRS-4.5_evaluated_by_AVG': 0.0782},
#  {'MOVING-AVG_evaluated_by_FSRS-4.5': 0.0715,
#   'FSRS-4.5_evaluated_by_MOVING-AVG': 0.0868},
#  {'FSRSv3_evaluated_by_FSRSv4': 0.117, 'FSRSv4_evaluated_by_FSRSv3': 0.0625},
#  {'SM-17_evaluated_by_FSRSv4': 0.1053, 'FSRSv4_evaluated_by_SM-17': 0.1138},
#  {'SM-16_evaluated_by_FSRSv4': 0.1073, 'FSRSv4_evaluated_by_SM-16': 0.0926},
#  {'AVG_evaluated_by_FSRSv4': 0.0655, 'FSRSv4_evaluated_by_AVG': 0.1078},
#  {'MOVING-AVG_evaluated_by_FSRSv4': 0.0684,
#   'FSRSv4_evaluated_by_MOVING-AVG': 0.115},
#  {'SM-17_evaluated_by_FSRSv3': 0.0984, 'FSRSv3_evaluated_by_SM-17': 0.1468},
#  {'SM-16_evaluated_by_FSRSv3': 0.0907, 'FSRSv3_evaluated_by_SM-16': 0.1239},
#  {'AVG_evaluated_by_FSRSv3': 0.053, 'FSRSv3_evaluated_by_AVG': 0.1419},
#  {'MOVING-AVG_evaluated_by_FSRSv3': 0.0557,
#   'FSRSv3_evaluated_by_MOVING-AVG': 0.1472},
#  {'SM-16_evaluated_by_SM-17': 0.119, 'SM-17_evaluated_by_SM-16': 0.0967},
#  {'AVG_evaluated_by_SM-17': 0.0474, 'SM-17_evaluated_by_AVG': 0.0879},
#  {'MOVING-AVG_evaluated_by_SM-17': 0.0522,
#   'SM-17_evaluated_by_MOVING-AVG': 0.0973},
#  {'AVG_evaluated_by_SM-16': 0.0521, 'SM-16_evaluated_by_AVG': 0.114},
#  {'MOVING-AVG_evaluated_by_SM-16': 0.054,
#   'SM-16_evaluated_by_MOVING-AVG': 0.1202},
#  {'MOVING-AVG_evaluated_by_AVG': 0.0328,
#   'AVG_evaluated_by_MOVING-AVG': 0.0476}]

# %%
import numpy as np

final_results = {}

for player in all_algorithms:
    universal_metrics = []
    for result in results:
        for key, value in result.items():
            if key.startswith(player):
                universal_metrics.append(value)
    final_results[player] = np.array(universal_metrics).mean().round(4)

# Sort by value (ascending, lower is better)
sorted_results = sorted(final_results.items(), key=lambda x: x[1])

# Display result in markdown table format, bold the best algorithm and its metric
print("| Algorithm | Universal Metric+↓ |")
print("|-----------|------------------|")
for i, (algo, metric) in enumerate(sorted_results):
    if i == 0:
        print(f"| **{algo}** | **{metric:.4f}** |")
    else:
        print(f"| {algo} | {metric:.4f} |")
# Out:
# | Algorithm | Universal Metric+↓ |
# |-----------|------------------|
# | **FSRS-6** | **0.0313** |
# | MOVING-AVG | 0.0600 |
# | AVG | 0.0603 |
# | FSRS-4.5 | 0.0700 |
# | FSRS-5 | 0.0719 |
# | SM-17 | 0.1012 |
# | FSRSv4 | 0.1028 |
# | SM-16 | 0.1132 |
# | FSRSv3 | 0.1387 |
